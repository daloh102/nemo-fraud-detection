# %%
Konfiguration & Imports für den Evaluator
Führe diese Zelle aus, um alle notwendigen Bibliotheken zu laden und den Pfad zur Validierungsdatei zu definieren.

# %%
import json
import re
import requests
import wandb
from pathlib import Path

# Pfad zur Validierungsdatei aus dem SFT-Schritt
VAL_FILE = Path("sft/validation_new.jsonl")
NIM_URL = "http://localhost:8000/v1/chat/completions"  # Nutzt den lokalen Chat-Endpunkt

print("✅ Evaluator-Konfiguration erfolgreich geladen!")
